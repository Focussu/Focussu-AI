# %%
import cv2
import matplotlib.pyplot as plt
import pickle as pkl
import pandas as pd
import numpy as np

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 3: Load the input image.


# STEP 4: Detect face landmarks from the input image.
with open('/home/hyun/focussu-ai/data/109.학습태도_및_성향_관찰_데이터/3.개방데이터/1.데이터/Training/01.원천데이터/TS_00_01_p/04-01-104-01-1-8-23082700000335-01-5_result.pkl', 'rb') as f:
    detection_result = pkl.load(f)
# with open('/home/hyun/focussu-ai/data/109.학습태도_및_성향_관찰_데이터/3.개방데이터/1.데이터/Training/01.원천데이터/TS_00_03_p/04-01-587-01-1-8-23090400000005-03-27_result.pkl', 'rb') as f:
#     detection_result = pkl.load(f)
# Out:
# 2025-05-20 11:31:22.789053: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-20 11:31:22.951484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747708283.009891    8603 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747708283.027867    8603 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# We will also visualize the face blendshapes categories using a bar graph.

# %%
print(type(detection_result.face_landmarks))
print(type(detection_result.face_blendshapes))
# Out:
# <class 'list'>
# <class 'list'>

# %%
landmarks = detection_result.face_landmarks
blendshapes = detection_result.face_blendshapes

# %%
if not detection_result.face_blendshapes:
    print("얼굴 표현이 감지되지 않았습니다.")
else:
    print("얼굴 표현이 감지되었습니다.")
    print(len(detection_result.face_blendshapes[0]))
    print(detection_result.face_blendshapes[0])
# Out:
# 얼굴 표현이 감지되었습니다.
# 52
# ...

# %% [markdown]
# And print the transformation matrix.

# %%
print(len(landmarks[0]))
print(landmarks[0])
# Out:
# 478
# ...

# %%
print(type(landmarks[0][0]))
for i in landmarks[0]:
    print(f'[x:{i.x:.3f}, {i.y:.3f}, {i.z:.3f}] - {i.visibility} | {i.presence}')
# Out:
# <class 'mediapipe.tasks.python.components.containers.landmark.NormalizedLandmark'>
# [x:0.453, 0.635, -0.017] - 0.0 | 0.0
# [x:0.451, 0.600, -0.057] - 0.0 | 0.0
# [x:0.452, 0.610, -0.025] - 0.0 | 0.0
# [x:0.441, 0.541, -0.051] - 0.0 | 0.0
# [x:0.451, 0.584, -0.063] - 0.0 | 0.0
# [x:0.450, 0.560, -0.062] - 0.0 | 0.0
# [x:0.450, 0.499, -0.043] - 0.0 | 0.0
# [x:0.373, 0.485, 0.002] - 0.0 | 0.0
# [x:0.449, 0.458, -0.042] - 0.0 | 0.0
# [x:0.449, 0.436, -0.048] - 0.0 | 0.0
# [x:0.447, 0.345, -0.053] - 0.0 | 0.0
# [x:0.453, 0.639, -0.015] - 0.0 | 0.0
# [x:0.453, 0.642, -0.011] - 0.0 | 0.0
# [x:0.453, 0.644, -0.004] - 0.0 | 0.0
# [x:0.452, 0.658, -0.004] - 0.0 | 0.0
# [x:0.452, 0.663, -0.004] - 0.0 | 0.0
# [x:0.453, 0.670, -0.005] - 0.0 | 0.0
# [x:0.453, 0.678, -0.002] - 0.0 | 0.0
# [x:0.454, 0.697, 0.010] - 0.0 | 0.0
# [x:0.452, 0.607, -0.050] - 0.0 | 0.0
# [x:0.441, 0.605, -0.035] - 0.0 | 0.0
# [x:0.324, 0.414, 0.041] - 0.0 | 0.0
# [x:0.404, 0.501, -0.008] - 0.0 | 0.0
# ...

# %%
print(len(blendshapes[0]))
print(type(blendshapes[0][0]))
print(blendshapes[0][0])

score = blendshapes[0][0].score
print(type(score))
print(score)
# Out:
# 52
# <class 'mediapipe.tasks.python.components.containers.category.Category'>
# Category(index=0, score=6.740320714015979e-06, display_name='', category_name='_neutral')
# <class 'float'>
# 6.740320714015979e-06

# %%
for i in blendshapes[0]:
    print(f'{i.index}: {i.category_name} ({i.score:.3f}) - [{i.display_name}]')
# Out:
# 0: _neutral (0.000) - []
# 1: browDownLeft (0.122) - []
# 2: browDownRight (0.077) - []
# 3: browInnerUp (0.005) - []
# 4: browOuterUpLeft (0.013) - []
# 5: browOuterUpRight (0.025) - []
# 6: cheekPuff (0.000) - []
# 7: cheekSquintLeft (0.000) - []
# 8: cheekSquintRight (0.000) - []
# 9: eyeBlinkLeft (0.133) - []
# 10: eyeBlinkRight (0.090) - []
# 11: eyeLookDownLeft (0.205) - []
# 12: eyeLookDownRight (0.209) - []
# 13: eyeLookInLeft (0.014) - []
# 14: eyeLookInRight (0.179) - []
# 15: eyeLookOutLeft (0.189) - []
# 16: eyeLookOutRight (0.019) - []
# 17: eyeLookUpLeft (0.052) - []
# 18: eyeLookUpRight (0.042) - []
# 19: eyeSquintLeft (0.588) - []
# 20: eyeSquintRight (0.448) - []
# 21: eyeWideLeft (0.006) - []
# 22: eyeWideRight (0.006) - []
# 23: jawForward (0.000) - []
# 24: jawLeft (0.001) - []
# 25: jawOpen (0.005) - []
# 26: jawRight (0.000) - []
# 27: mouthClose (0.000) - []
# 28: mouthDimpleLeft (0.047) - []
# 29: mouthDimpleRight (0.031) - []
# ...

# %%
import torch
print(torch.zeros((3,2)))
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
